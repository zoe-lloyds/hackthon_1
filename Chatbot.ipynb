# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/d1/8d/e5d5c0573346db3168641f0c662d2d68ba25c2f8d5197b37d67947333465/streamlit-1.23.1-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.23.1-py2.py3-none-any.whl.metadata (7.4 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/b2/20/5c3b89d6f8d9938325a9330793438389e0dc94c34d921f6da35ec62095f3/altair-5.0.1-py3-none-any.whl.metadata
#   Downloading altair-5.0.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/bf/2b/11bcedb7dee4923253a4a21bae3be854bcc4f06295bd827756352016d97c/blinker-1.6.3-py3-none-any.whl.metadata
#   Downloading blinker-1.6.3-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/conda/lib/python3.7/site-packages (from streamlit) (4.2.4)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.7/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /opt/conda/lib/python3.7/site-packages (from streamlit) (4.11.4)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.7/site-packages (from streamlit) (1.21.6)
# Requirement already satisfied: packaging<24,>=14.1 in /opt/conda/lib/python3.7/site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=0.25 in /opt/conda/lib/python3.7/site-packages (from streamlit) (1.3.5)
# Requirement already satisfied: pillow<10,>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from streamlit) (9.5.0)
# Collecting protobuf<5,>=3.20 (from streamlit)
#   Obtaining dependency information for protobuf<5,>=3.20 from https://files.pythonhosted.org/packages/c8/2c/03046cac73f46bfe98fc846ef629cf4f84c2f59258216aa2cc0d22bfca8f/protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Requirement already satisfied: pyarrow>=4.0 in /opt/conda/lib/python3.7/site-packages (from streamlit) (6.0.1)
# Collecting pympler<2,>=0.9 (from streamlit)
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3,>=2 in /opt/conda/lib/python3.7/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.4 in /opt/conda/lib/python3.7/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.11.0 in /opt/conda/lib/python3.7/site-packages (from streamlit) (13.5.3)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /opt/conda/lib/python3.7/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2 in /opt/conda/lib/python3.7/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in /opt/conda/lib/python3.7/site-packages (from streamlit) (4.7.1)
# Collecting tzlocal<5,>=1.1 (from streamlit)
#   Obtaining dependency information for tzlocal<5,>=1.1 from https://files.pythonhosted.org/packages/55/a6/a75af44665e5e77e52f6789eef4f8bc056c8e039d96c804b975806942580/tzlocal-4.3.1-py3-none-any.whl.metadata
#   Downloading tzlocal-4.3.1-py3-none-any.whl.metadata (14 kB)
# Collecting validators<1,>=0.2 (from streamlit)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in /opt/conda/lib/python3.7/site-packages (from streamlit) (3.1.37)
# Collecting pydeck<1,>=0.1.dev5 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 82.3 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/conda/lib/python3.7/site-packages (from streamlit) (6.2)
# Collecting watchdog (from streamlit)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.7/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.7/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.7/site-packages (from gitpython!=3.1.19,<4,>=3->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas<3,>=0.25->streamlit) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.4->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.7/site-packages (from rich<14,>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.7/site-packages (from rich<14,>=10.11.0->streamlit) (2.16.1)
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting backports.zoneinfo (from tzlocal<5,>=1.1->streamlit)
#   Downloading backports.zoneinfo-0.2.1-cp37-cp37m-manylinux1_x86_64.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=3.4.0 in /opt/conda/lib/python3.7/site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (5.12.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.7/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit) (0.1.2)
# Collecting tzdata (from pytz-deprecation-shim->tzlocal<5,>=1.1->streamlit)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 41.2 MB/s eta 0:00:00
# Downloading streamlit-1.23.1-py2.py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 65.7 MB/s eta 0:00:0000:01:00:01
# Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.5/471.5 kB 24.2 MB/s eta 0:00:00
# Downloading blinker-1.6.3-py3-none-any.whl (13 kB)
# Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 36.9 MB/s eta 0:00:00
# Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19575 sha256=ac22a230ca7adebab9fdd9e7990871692a070ded3af8c9a28967e78247109840
#   Stored in directory: /home/jupyter/.cache/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# Installing collected packages: watchdog, validators, tzdata, pympler, protobuf, blinker, backports.zoneinfo, pytz-deprecation-shim, pydeck, tzlocal, altair, streamlit
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# apache-beam 2.46.0 requires protobuf<4,>3.12.2, but you have protobuf 4.24.4 which is incompatible.
# google-api-core 1.34.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.24.4 which is incompatible.
# google-cloud-bigtable 1.7.3 requires protobuf<4.0.0dev, but you have protobuf 4.24.4 which is incompatible.
# google-cloud-datastore 1.15.5 requires protobuf<4.0.0dev, but you have protobuf 4.24.4 which is incompatible.
# google-cloud-language 1.3.2 requires protobuf<4.0.0dev, but you have protobuf 4.24.4 which is incompatible.
# google-cloud-pubsub 2.18.4 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.48.1 which is incompatible.
# google-cloud-videointelligence 1.16.3 requires protobuf<4.0.0dev, but you have protobuf 4.24.4 which is incompatible.
# tensorboard 2.11.2 requires protobuf<4,>=3.9.2, but you have protobuf 4.24.4 which is incompatible.
# tensorboardx 2.6 requires protobuf<4,>=3.8.0, but you have protobuf 4.24.4 which is incompatible.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.4 which is incompatible.
# tensorflow-metadata 1.12.0 requires protobuf<4,>=3.13, but you have protobuf 4.24.4 which is incompatible.
# tensorflow-serving-api 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.4 which is incompatible.
# tensorflow-transform 1.12.0 requires protobuf<4,>=3.13, but you have protobuf 4.24.4 which is incompatible.
# tfx-bsl 1.12.0 requires protobuf<4,>=3.13, but you have protobuf 4.24.4 which is incompatible.
# Successfully installed altair-5.0.1 backports.zoneinfo-0.2.1 blinker-1.6.3 protobuf-3.20.1 pydeck-0.8.1b0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 streamlit-1.23.1 tzdata-2023.3 tzlocal-4.3.1 validators-0.20.0 watchdog-3.0.0

# %%
from openai import OpenAI
import streamlit as st

# %%
with st.sidebar:
    openai_api_key = st.text_input("OpenAI API Key", key="chatbot_api_key", type="password")
    "[Get an OpenAI API key](https://platform.openai.com/account/api-keys)"
    "[View the source code](https://github.com/streamlit/llm-examples/blob/main/Chatbot.py)"
    "[![Open in GitHub Codespaces](https://github.com/codespaces/badge.svg)](https://codespaces.new/streamlit/llm-examples?quickstart=1)"

st.title("Help and Support Assistant")
st.caption("Powered by OpenAI LLM")
if "messages" not in st.session_state:
    st.session_state["messages"] = [{"role": "assistant", "content": "How can I help you?"}]

for msg in st.session_state.messages:
    st.chat_message(msg["role"]).write(msg["content"])

if prompt := st.chat_input():
    if not openai_api_key:
        st.info("Please add your OpenAI API key to continue.")
        st.stop()

    client = OpenAI(api_key=openai_api_key)
    st.session_state.messages.append({"role": "user", "content": prompt})
    st.chat_message("user").write(prompt)
    response = client.chat.completions.create(model="gpt-3.5-turbo", messages=st.session_state.messages)
    msg = response.choices[0].message.content
    st.session_state.messages.append({"role": "assistant", "content": msg})
    st.chat_message("assistant").write(msg)
